# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
merged_df = pd.read_stata('FinalDataset.dta',index_col = 'id')

# %%
merged_df.head()
# Out:
#                  Mom_Age  Education_level  Wealth_index  Mothers_BMI  \
# id
#   0100101357 02       39                1             1       2213.0
#   0100101395 02       35                2             0       3041.0
#   0100101380 02       32                2             2       5255.0
#   0100103022 04       29                2             4       3063.0
#   0100103098 02       28                2             3       2338.0
#
#                  Child_anaemia  Birth_order  Age  Size_of_child  \
# id
#   0100101357 02              3            4  1.0              2
#   0100101395 02              2            1  2.0              2
#   0100101380 02              2            2  3.0              3
#   0100103022 04              2            1  4.0              2
#   0100103098 02              0            1  0.0              2
#
#                  Respondent_anaemic_level  BMI_std  Sex_female  \
# id
#   0100101357 02                         2   -206.0           1
# ...

# %%
plt.figure(figsize=(16,16))
corr_matrix = merged_df.corr()

# Create a heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

# Show the plot
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(criterion='gini',max_depth=2,min_samples_leaf=0.14)

# %%
from sklearn.model_selection import train_test_split

# %%
X = merged_df.drop(columns=['nutritionalStatus'])
y = merged_df['nutritionalStatus']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=0.14)

# %%
y_pred = dt.predict(X_test)

# %%
accuracy = dt.score(X_test,y_test)
accuracy
# Out:
# 0.6552310579404176

# %%
n = len(merged_df)
print(n)
cols = ['Education_level','Wealth_index','Child_anaemia','Birth_order','Age','Size_of_child','Respondent_anaemic_level']
for col in cols:
    print("\n")
    print(col)
    print("Nutritional Status = 1\n", merged_df[merged_df['nutritionalStatus'] == 1][col].value_counts())
    print("\n")
    print("Nutritional Status = 0\n", merged_df[merged_df['nutritionalStatus'] == 0][col].value_counts())
    print("\n")
    
   
    # Append the 3 statements as a row to the DataFrame
    df = df.append({'Print 1': print_1, 'Print 2': print_2, 'Print 3': print_3}, ignore_index=True)
    
    print("Total values \n")
    print(merged_df[col].value_counts())
# Out:
# 155018
#
#
# Education_level
# Nutritional Status = 1
#  2    46085
# 3    15300
# 0    14059
# 1     9321
# Name: Education_level, dtype: int64
#
#
# Nutritional Status = 0
#  2    35776
# 0    17067
# 1     9797
# 3     7613
# Name: Education_level, dtype: int64
#
#
# Total values
#
# 2    81861
# 0    31126
# 3    22913
# 1    19118
# Name: Education_level, dtype: int64
#
#
# Wealth_index
# Nutritional Status = 1
#  4    18278
# 1    17092
# 2    16921
# 3    16358
# 0    16116
# Name: Wealth_index, dtype: int64
#
#
# Nutritional Status = 0
#  0    19367
# 1    16492
# 2    13700
# 3    11469
# 4     9225
# Name: Wealth_index, dtype: int64
#
#
# Total values
#
# 0    35483
# 1    33584
# 2    30621
# 3    27827
# 4    27503
# Name: Wealth_index, dtype: int64
#
#
# Child_anaemia
# Nutritional Status = 1
#  0    36234
# 2    24676
# 1    22021
# 3     1834
# Name: Child_anaemia, dtype: int64
#
#
# Nutritional Status = 0
#  0    27788
# 2    22285
# 1    18386
# 3     1794
# ...

# %%
lab_cols = ['Residence_rural', 'Diarrhea_yes, last two weeks', 'Fever_yes', 'Vitamin_A_yes']
for col in lab_cols:
    print("\n")
    print(col)
    print("Nutritional Status = 1\n", merged_df[merged_df['nutritionalStatus'] == 1][col].value_counts())
    print("\n")
    print("Nutritional Status = 0\n", merged_df[merged_df['nutritionalStatus'] == 0][col].value_counts())
    print("\n")
    
    print("Total values \n")
    print(merged_df[col].value_counts())
# Out:
#   Input In [24]
#
#     ^
# SyntaxError: incomplete input
